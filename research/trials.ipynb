# %% [markdown]
# ##Download data from gdrive

# %%
import gdown

# %%
url = "https://drive.google.com/file/d/1nY4Xm4GekPf0ZWRuFCfS43jXOfiR8LAc/view?usp=sharing"

# %%
url.split('/')
# Out:
# ['https:',
#  '',
#  'drive.google.com',
#  'file',
#  'd',
#  '1nY4Xm4GekPf0ZWRuFCfS43jXOfiR8LAc',
#  'view?usp=sharing']

# %%
url.split('/')[-2]
# Out:
# '1nY4Xm4GekPf0ZWRuFCfS43jXOfiR8LAc'

# %%
file_id = url.split('/')[-2]
file_id
# Out:
# '1nY4Xm4GekPf0ZWRuFCfS43jXOfiR8LAc'

# %%
prefix = "https://drive.google.com/uc?export=download&id="
gdown.download(prefix + file_id, "Chest-CT-Scan-data.zip")
# Out:
# Downloading...
# From (original): https://drive.google.com/uc?export=download&id=1nY4Xm4GekPf0ZWRuFCfS43jXOfiR8LAc
# From (redirected): https://drive.google.com/uc?export=download&id=1nY4Xm4GekPf0ZWRuFCfS43jXOfiR8LAc&confirm=t&uuid=acebc4ad-f085-419c-a0e0-f789cf28f68b
# To: d:\Project\Cheast Disease Classification\research\Chest-CT-Scan-data.zip
# 100%|██████████| 49.0M/49.0M [00:02<00:00, 23.5MB/s]
# 'Chest-CT-Scan-data.zip'
